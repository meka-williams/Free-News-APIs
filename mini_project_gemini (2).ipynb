# %%
import requests
import json
import google.generativeai as genai
from google.colab import userdata
import pprint
from google import genai

news_key=userdata.get("CURRENT_KEY")
gemma=userdata.get("GOOGLE_API_KEY")

# %%
# Create Gemini client
client = genai.Client(api_key=gemma)

#utility method to talk the Gemini
def get_response(prompt, model='gemini-2.0-flash-lite'):
    response = client.models.generate_content(
        model=model,
        contents=prompt
    )
    return response.text

# %%
#testing get_response
get_response("What is a zero shot prompt?")
# Out:
# 'A zero-shot prompt is a way to get a language model (like GPT-3 or similar) to perform a task **without** providing it with any examples of the desired input-output mapping. In other words, you ask it to do something it\'s never explicitly been trained on *with examples*.\n\nHere\'s a breakdown:\n\n* **Zero Examples:**  The "zero-shot" part means you\'re providing *zero* examples in your prompt to demonstrate the desired behavior.  You\'re not showing it how to do it.\n\n* **Prompt Engineering:** You rely on carefully crafting your prompt to clearly define the task you want the model to perform. This is key.  The prompt has to be very specific and unambiguous.\n\n* **Leveraging Pre-existing Knowledge:**  The power of zero-shot learning comes from the language model\'s massive training dataset. It implicitly learns a lot of world knowledge, relationships, and patterns from the vast amount of text it\'s been exposed to.  You\'re hoping it can apply this general knowledge to a specific task.\n\n**Think of it like this:**\n\nImagine teaching a child a new word.\n\n* **Example-Based Learning (Few-Shot or Fine-Tuning):**  You show the child several pictures of apples and say "apple" each time.  Then you show a picture of a banana and ask "What is this?".\n\n* **Zero-Shot Learning:** You never show the child any examples of apples or use the word "apple." Instead, you say something like, "There is a fruit that is often red, grows on trees, and is considered healthy.  What is it called?" The child might be able to answer "apple" based on their existing knowledge of fruits.\n\n**Here\'s a simple example using a hypothetical language model:**\n\n**Task:** Translate English to French.\n\n* **Few-Shot Prompt (with Examples):**\n\n   ```\n   English: The sky is blue.\n   French: Le ciel est bleu.\n\n   English: I like to eat pizza.\n   French: J\'aime manger de la pizza.\n\n   English: The weather is nice today.\n   French:\n   ```\n\n* **Zero-Shot Prompt:**\n\n   ```\n   Translate the following English sentence to French: The weather is nice today.\n   ```\n\n**Why is zero-shot learning important?**\n\n* **Adaptability:**  It allows you to use a language model for a wider range of tasks without needing to collect and label large datasets for each new task.\n\n* **Cost-Effective:** It can be significantly cheaper than fine-tuning or using few-shot learning because you don\'t need to train the model on specific examples.\n\n* **Rapid Prototyping:** You can quickly test ideas and see if a language model can perform a task before investing time and resources into creating training data.\n\n**Limitations of Zero-Shot Learning:**\n\n* **Performance:** Zero-shot performance is often lower than few-shot or fine-tuned models.\n\n* **Prompt Sensitivity:**  The specific wording of the prompt can have a significant impact on the quality of the results.  It requires careful prompt engineering.\n\n* **Hallucinations:**  Language models can sometimes "hallucinate" or generate incorrect or nonsensical information, especially in zero-shot settings.\n\n* **Bias:**  The model can reflect biases present in its training data, which can lead to unfair or discriminatory outcomes.\n\n**In summary, a zero-shot prompt is a request to a language model to perform a task without providing any examples. It relies on the model\'s general knowledge and the careful crafting of the prompt to guide the model\'s response.**\n'

# %%
#querying current api for health related articles
url = f'https://api.currentsapi.services/v1/search?keywords=Health&language=en&page_size=150&apiKey={news_key}'
response = requests.get(url)
data=response.json()
print(data)
print(f"Total Results: {len(data.get('news', []))}")  # Access 'news' from JSON data
# Out:
# {'status': 'ok', 'news': [{'id': 'bdbb4398-f7d9-4135-b3e8-74f3071e891f', 'title': "Johor's NADI Centres Now Provide Free Health Screenings", 'description': 'BATU PAHAT, March 8 (Bernama) -- The role of the National Information Dissemination Centre (NADI) in Johor has been expanded to include basic health facilities instead of serving only as an informatio...', 'url': 'https://www.bernama.com/en/news.php/?id=2400285', 'author': 'BERNAMA', 'image': 'https://www.bernama.com/storage/photos/ff2374bcecd00c38cd754f4dec5dc32067cbd32fd78eb-medium', 'language': 'en', 'category': ['regional'], 'published': '2025-03-08 05:39:28 +0000'}, {'id': 'cc7bfc61-3f1a-40a9-9e38-3eb503fb2919', 'title': 'MPS, health officials announce lead testing clinics for students', 'description': 'DOING OKAY. NEW AT TEN. THE MILWAUKEE SCHOOL CLOSED LAST WEEK BECAUSE OF LEAD WILL NOT REOPEN ON MONDAY. DISTRICT OFFICIALS SAY CREWS STILL NEED TO DO MORE DEEP CLEANING AT TROWBRIDGE STREET SCHOOL TH...', 'url': 'https://www.wisn.com/article/mps-health-officials-announce-lead-testing-clinics-for-students/64097776', 'author': 'Hannah Hilyard', 'image': 'https://kubrick.htvapps.com/htv-prod-media.s3.amazonaws.com/images/poster-image-2-67cb9871e0210.jpg?crop=0.739xw:0.739xh;0.0700xw,0&resize=1200:*', 'language': 'en', 'category': ['regional', 'milwaukee', 'wisconsin'], 'published': '2025-03-08 04:14:00 +0000'}, {'id': '92fcb8c5-fc6d-46db-90bc-fe074cfab7ef', 'title': 'Former NIH Director Francis Collins Sings Song at Science Rally', 'description': 'Francis Collins, the former Director of the National Institutes of Health, sang a song at a "Stand up for Science" rally in Washington, DC.', 'url': 'https://www.breitbart.com/politics/2025/03/07/former-nih-director-francis-collins-sings-song-science-rally/', 'author': 'Elizabeth Weibel', 'image': 'https://media.breitbart.com/media/2025/03/francis-collins-stand-up-for-science-rally-3-7-25-getty.jpg', 'language': 'en', 'category': ['politics'], 'published': '2025-03-08 03:44:46 +0000'}, {'id': 'cd0956a3-6b65-4669-9ab2-d0fab4f5f9ae', 'title': 'Study identifies two new health issues as dementia risk factors', 'description': 'You could be at risk and not know it...', 'url': 'https://www.express.co.uk/life-style/health/2023361/health-dementia-risk-factors-expert', 'author': 'news', 'image': 'None', 'language': 'en', 'category': ['regional'], 'published': '2025-03-08 03:16:00 +0000'}, {'id': '07daa34c-59fd-43d9-8cdd-5c094a06a329', 'title': 'C.D.C. Will Investigate Debunked Link Between Vaccines and Autism', 'description': 'Asked in an interview about the C.D.C.’s plans to re-examine whether autism is connected to vaccination, Xavier Becerra, health secretary to President Joseph R. Biden Jr., said, “All I’ll say is that ...', 'url': 'https://www.nytimes.com/2025/03/07/health/vaccines-autism-cdc-rfk-jr.html', 'author': 'Emily Baumgaertner Nunn', 'image': 'https://static01.nyt.com/images/2025/02/10/multimedia/07trump-news-vaccines-autism1/dc-kennedy-vaccines4-gzck-facebookJumbo.jpg', 'language': 'en', 'category': ['general'], 'published': '2025-03-08 03:01:20 +0000'}, {'id': '95e5e186-a04f-4782-8d30-69b223577d40', 'title': 'Red Cross Heroes:\xa0Easton teacher creates student program that grants access to free local health care', 'description': "FRESNO COUNTY, Calif. (KGPE) – The American Red Cross is honoring its 2025 Central Valley heroes – individuals recognized for their extraordinary acts of courage, kindness and compassion.\xa0This year's community impact hero is Tony Pena whose work brought opportunities to students and health care to a...", 'url': 'https://www.yourcentralvalley.com/news/red-cross-heroes/red-cross-heroes-easton-teacher-creates-student-program-that-grants-access-to-free-local-health-care/', 'author': 'Kathryn Herr', 'image': 'None', 'language': 'en', 'category': ['regional', 'fresno', 'california'], 'published': '2025-03-08 02:27:01 +0000'}, {'id': '6a119b95-36d1-45eb-b36b-57868714bf46', 'title': "Fearne Cotton's ' ...
# Total Results: 150

# %%
#display sample article
pprint.pprint(data['news'][65])
# Out:
# {'author': 'Joseph Choi',
#  'category': ['insurance', 'health'],
#  'description': 'The Centers for Disease Control and Prevention (CDC) '
#                 'published a webpage Friday listing the conflicts of interest '
#                 'reported by members of a key vaccine advisory committee.\n'
#                 'Health and Human Services (HHS) Secretary Robert F. Kennedy '
#                 'Jr. hailed it as another step toward "radical transparency," '
#                 'while on...',
#  'id': '288ba563-12f6-4708-9e79-b74c53f2e762',
#  'image': 'None',
#  'language': 'en',
#  'published': '2025-03-07 21:08:05 +0000',
#  'title': "CDC launches 'conflicts of interest' page about vaccine advisory "
#           'panel',
#  'url': 'https://thehill.com/policy/healthcare/5183223-cdc-vaccine-advisory-committee-conflicts/'}

# %%
#preprocessing retrieved articles: handeling duplicates and missing data
def preprocess_articles(articles):
    print(f"Starting preprocessing on {len(articles)} articles")
    original_article = data.get('news', [])[90]
    print("\nOriginal article keys:")
    print(sorted(original_article.keys()))

    seen_urls = set()
    preprocessed_articles = []
    for article in articles:
      #skip articles without url
        url = article.get('url')
        if not url:
            continue
        #skip duplicate urls
        if url in seen_urls:
            continue
        seen_urls.add(url)
        processed_article = {
            "id": article.get("id", ""),
            "title": "PROCESSED: " + article.get("title", "No title available"),  # Add a prefix to verify
            "description": article.get("description", "No description available"),
            "url": url,
            "author": article.get("author", "Unknown"),
            "image": article.get("image", ""),
            "language": article.get("language", "en"),
            "category": article.get("category", []),
            "published": article.get("published", "na"),
        }
        # Skip articles with empty titles and descriptions (both missing)
        if processed_article["title"] == "No title available" and processed_article["description"] == "No description available":
            continue
        preprocessed_articles.append(processed_article)
    return preprocessed_articles

processed_data = preprocess_articles(data.get('news', []))

print(f"Total articles after preprocessing: {len(processed_data)}")

#print sample original article
print("\nOriginal article:")
pprint.pprint(data.get('news', [])[17])

#print sample preprocessed article
print("\nPreprocessed article:")
pprint.pprint(processed_data[17])
# Out:
# Starting preprocessing on 150 articles
#
# Original article keys:
# ['author', 'category', 'description', 'id', 'image', 'language', 'published', 'title', 'url']
# Total articles after preprocessing: 150
#
# Original article:
# {'author': 'Jessica Patterson',
#  'category': ['regional', 'springfield', 'massachusetts'],
#  'description': 'MARTIN COUNTY, KY (WOWK) - As communities across the region '
#                 "continue to rebuild after February's catastrophic flooding, "
#                 'efforts are still underway to lend a hand to those in need.\n'
#                 'Thanks to the generosity of others, the Martin County Health '
#                 "Department's Rebuilding Joy Initiative collected thousands "
#                 '...',
#  'id': 'f285f03f-5c7c-4e16-a511-87dabaaa0f70',
#  'image': 'None',
#  'language': 'en',
#  'published': '2025-03-07 23:52:09 +0000',
#  'title': 'Martin County rebuilds joy for kids with toy drive after floods',
#  'url': 'https://www.wowktv.com/news/kentucky/martin-county-ky/martin-county-rebuilds-joy-for-kids-with-toy-drive-after-floods/'}
#
# Preprocessed article:
# {'author': 'Jessica Patterson',
#  'category': ['regional', 'springfield', 'massachusetts'],
#  'description': 'MARTIN COUNTY, KY (WOWK) - As communities across the region '
#                 "continue to rebuild after February's catastrophic flooding, "
#                 'efforts are still underway to lend a hand to those in need.\n'
#                 'Thanks to the generosity of others, the Martin County Health '
#                 "Department's Rebuilding Joy Initiative collected thousands "
#                 '...',
#  'id': 'f285f03f-5c7c-4e16-a511-87dabaaa0f70',
#  'image': 'None',
#  'language': 'en',
#  'published': '2025-03-07 23:52:09 +0000',
#  'title': 'PROCESSED: Martin County rebuilds joy for kids with toy drive after '
#           'floods',
#  'url': 'https://www.wowktv.com/news/kentucky/martin-county-ky/martin-county-rebuilds-joy-for-kids-with-toy-drive-after-floods/'}
